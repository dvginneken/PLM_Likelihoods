# %%
import pandas as pd
import anndata
import evolocity as evo
import scanpy as sc
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # All mice sequences (full length VDJ)

# %%
adata_mice = sc.read_h5ad("PLM_Likelihoods/data/OVA_V7/evo-velocity/adata_AllSamples_full_VDJ_esm.h5ad")
print(adata_mice)
# Out:
# AnnData object with n_obs × n_vars = 6002 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ## Figure 4C (left)

# %%
ax = evo.pl.velocity_embedding_stream(adata_mice, color="v_gene_family", legend_loc="right margin")

# %% [markdown]
# ## Figure 4D (left)

# %%
ax = evo.pl.velocity_embedding_stream(adata_mice, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Supplementary Figure 5 (left)

# %%
ax = evo.pl.velocity_embedding_stream(adata_mice, color="sample", legend_loc="right margin")

# %% [markdown]
# # All human sequences (full length VDJ)

# %%
adata_human = sc.read_h5ad("PLM_Likelihoods/data/adata_AllHumanSamples_full_VDJ_esm.h5ad")
print(adata_human)
# Out:
# AnnData object with n_obs × n_vars = 17624 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'clonotype', 'v_gene_family', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ## Figure 4C (right)

# %%
ax = evo.pl.velocity_embedding_stream(adata_human, color="v_gene_family", legend_loc="right margin")

# %% [markdown]
# ## Figure 4D (right)

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="SHM_count", legend_loc="right margin")

# %% [markdown]
# ## Supplementary Figure 5 (right)

# %%
ax = evo.pl.velocity_embedding_stream(adata, color="sample", legend_loc="right margin")

# %% [markdown]
# # Mice V-gene subfamilies

# %% [markdown]
# ## Figure 4E (left)

# %%
adata_56 = sc.read_h5ad("PLM_Likelihoods/data/OVA_V7/evo-velocity/adata_IGHV5-6_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_56)
# Out:
# AnnData object with n_obs × n_vars = 153 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_56, color="isotype", legend_loc="right margin", title="IGHV5-6")

# %% [markdown]
# ## Supplementary Figure 6 (left)

# %%
adata_31 = sc.read_h5ad("PLM_Likelihoods/data/OVA_V7/evo-velocity/adata_IGHV3-1_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_31)
# Out:
# AnnData object with n_obs × n_vars = 126 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_31, color="isotype", legend_loc="right margin", title="IGHV3-1")

# %%
adata_93 = sc.read_h5ad("PLM_Likelihoods/data/OVA_V7/evo-velocity/adata_IGHV9-3_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_93)
# Out:
# AnnData object with n_obs × n_vars = 172 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_93, color="isotype", legend_loc="right margin", title="IGHV9-3")

# %% [markdown]
# # Human V-gene subfamilies

# %% [markdown]
# ## Figure 4E (right)

# %%
adata_323 = sc.read_h5ad("PLM_Likelihoods/data/adata_IGHV3-23_IncludingGermline_v_gene_only_esm.h5ad")
print(adata_323)
# Out:
# AnnData object with n_obs × n_vars = 950 × 1280
#     obs: 'seq', 'isotype', 'SHM_count', 'sample', 'v_gene', 'velocity_self_transition'
#     uns: 'neighbors', 'umap', 'velocity_graph', 'velocity_graph_neg'
#     obsm: 'X_umap', 'velocity_umap'
#     layers: 'velocity'
#     obsp: 'connectivities', 'distances'

# %%
ax = evo.pl.velocity_embedding_stream(adata_323, color="isotype", legend_loc="right margin", title="IGHV3-23")
